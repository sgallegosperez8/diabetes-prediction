# %% [markdown]
# # DIABETES WORKFLOW

# %% [markdown]
# ## Data-Preprocessing

# %% [markdown]
# Import diabetes data set

# %%
import pandas as pd

# %%
diabetes = pd.read_csv("diabetes_prediction_dataset.csv")

# %% [markdown]
# ## Data Wrangling
# Checked the data for na and null values. Also filtered data sets by women and by age groups 18 and under, 19-30, 31-45, and 45 and above

# %%
diabetes_women = diabetes.query('gender == "Female"')
diabetes = diabetes_women.sort_values("age",ascending=True)

# %% [markdown]
# There is no na values

# %%
diabetes_women.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# There is no null values

# %%
diabetes_women.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# Filtering by age groups into seperate dataframes

# %%
diabetes_w_18 = diabetes_women.query('age <= 18.0')
diabetes_w_18.sort_values("age",ascending=True)
diabetes_w_18["age"].unique()
# Out:
# array([ 4.  , 15.  ,  3.  , 13.  , 11.  ,  6.  ,  9.  , 12.  ,  5.  ,
#        17.  ,  0.08,  0.56, 14.  , 16.  ,  0.16, 18.  ,  2.  ,  7.  ,
#        10.  ,  8.  ,  1.16,  0.88,  1.56,  1.88,  1.24,  1.8 ,  0.72,
#         1.4 ,  1.  ,  0.4 ,  0.32,  1.08,  0.24,  0.8 ,  1.72,  0.64,
#         1.64,  1.32,  0.48,  1.48])
